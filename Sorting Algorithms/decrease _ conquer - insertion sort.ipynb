# %% [markdown]
# ## Insertion Sort

# %% [markdown]
# Recursive - top down
#
# *** If you save the current element in a separate variable, you optimize your processing because instead of 2 swaps, you do only 1 right shift.

# %%
def InsertionSort(values, n): 

  #copy the last element
  current = values[n-1]

  #go reverse order
  for j in range(0, n-1):

    index = n-1-j
    print(values[index])
    # if values[j] > values[j+1]:
    #   values[j]

# %% [markdown]
# Iterative - bottom up

# %%
array = [10, 9, 8, 7, 6]
InsertionSort(array, len(array))
# Out:
# 6
# 7
# 8
# 9

# %% [markdown]
# using while? go backwards...

# %%
def InsertionSort(values): 
 
  #go over the array
  for i in range(1, len(values)):

    print("index i ", i, "current v ", values[i])
    
    #copy the last element
    current = values[nth]
    print(current)
    

    #creates the pointer 
    j = nth - 1 -i

    while j >= 0 and current < values[j]:
      
      print("* position pointer: ", j, "value compared: ", values[j])  
      j = j-1
    
    
    # #j receives the total of items that is nth 
    # j = nth -i
    
    # print(nth, j)
    
    # #for each value lets compare. second loop
    # while j>=1 and current < values[j-1]:
    #   print("current ", values[nth], "value j", values[j], " array: ", values)
    #   values[j] = values[j-1]
    #   j = j-1
      

    # return
    # values[i] =  values[nth]
    # print("over ", "current ", values[nth], "value j", values[j], " array", values)

# %%
array = [10,  8, 7,  6]
InsertionSort(array)
# Out:
# index i  1 current v  8
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-224-bf95524cc06d> in <module>()
#       1 array = [10,  8, 7,  6]
# ----> 2 InsertionSort(array)
#
# <ipython-input-223-a5aa79a25894> in InsertionSort(values)
#       7
#       8     #copy the last element
# ----> 9     current = values[nth]
#      10     print(current)
#      11
#
# NameError: name 'nth' is not defined
